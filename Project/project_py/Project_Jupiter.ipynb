# %%
import pandas as pd
import numpy as np

import sys
reload(sys)
sys.setdefaultencoding('utf-8')

# %%
df = pd.read_csv("Data/fakeData_rus.csv", delimiter=",", encoding="utf-8",nrows=5)

# %%
df
# Out:
#    UserId          City                Region product
# 0       1  Екатеринбург  Свердловская область     КЭП
# 1       2       Puushma                   SVE     KEP
# 2       3         Piter                   SPB     KEP
# 3       4    Novouralsk                   SVE     ETP
# 4       5        Moscow                   MSK     ETP

# %%
df["Region"].unique()
# Out:
# array([ u'\u0421\u0432\u0435\u0440\u0434\u043b\u043e\u0432\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c',
#        u'SVE', u'SPB', u'MSK', u'PERM'], dtype=object)

# %%
original_columns = df.columns
df.columns
# Out:
# Index([u'UserId', u'City', u'Region', u'product'], dtype='object')

# %%
for x in df.columns:
    print x

# %%
for x in df.columns:
    print df[x].unique()

# %%
column_element_pairs = []
for colunm in df.columns:
    for element in df[colunm].unique():
        column_element_pairs.append("{}:{}".format(colunm,element))
column_element_pairs
# Out:
# ['UserId:1',
#  'UserId:2',
#  'UserId:3',
#  'UserId:4',
#  'UserId:5',
#  'UserId:6',
#  'UserId:7',
#  'UserId:8',
#  'UserId:9',
#  'UserId:10',
#  'City:\xd0\x95\xd0\xba\xd0\xb0\xd1\x82\xd0\xb5\xd1\x80\xd0\xb8\xd0\xbd\xd0\xb1\xd1\x83\xd1\x80\xd0\xb3',
#  'City:Puushma',
#  'City:Piter',
#  'City:Novouralsk',
#  'City:Moscow',
#  'City:Puschkin',
#  'City:Ramenki',
#  'City:Zelenograd',
#  'City:Perm',
#  'City:Kungur',
#  'Region:\xd0\xa1\xd0\xb2\xd0\xb5\xd1\x80\xd0\xb4\xd0\xbb\xd0\xbe\xd0\xb2\xd1\x81\xd0\xba\xd0\xb0\xd1\x8f \xd0\xbe\xd0\xb1\xd0\xbb\xd0\xb0\xd1\x81\xd1\x82\xd1\x8c',
#  'Region:SVE',
#  'Region:SPB',
#  'Region:MSK',
#  'Region:PERM',
#  'product:\xd0\x9a\xd0\xad\xd0\x9f',
#  'product:KEP',
#  'product:ETP']

# %%
features_df = pd.DataFrame(columns=column_element_pairs)

# %%
features_df
# Out:
# Empty DataFrame
# Columns: [UserId:1, UserId:2, UserId:3, UserId:4, UserId:5, UserId:6, UserId:7, UserId:8, UserId:9, UserId:10, City:Екатеринбург, City:Puushma, City:Piter, City:Novouralsk, City:Moscow, City:Puschkin, City:Ramenki, City:Zelenograd, City:Perm, City:Kungur, Region:Свердловская область, Region:SVE, Region:SPB, Region:MSK, Region:PERM, product:КЭП, product:KEP, product:ETP]
# Index: []
#
# [0 rows x 28 columns]

# %%
column_element_pairs = []
newdf = pd.DataFrame(df)

for colunm in df.columns:
    for element in df[colunm].unique():
        newdf["{}:{}".format(colunm,element)] = np.nan

# %%
# newdf.drop(["1"],inplace=True)

# %%
newdf.loc[1]["UserId:1"]
# Out:
# nan

# %%
newdf.set_value(1,"UserId:2",1)
# Out:
#    UserId          City                Region product  UserId:1  UserId:2  \
# 0       1  Екатеринбург  Свердловская область     КЭП       NaN       NaN
# 1       2       Puushma                   SVE     KEP       NaN       1.0
# 2       3         Piter                   SPB     KEP       NaN       NaN
# 3       4    Novouralsk                   SVE     ETP       NaN       NaN
# 4       5        Moscow                   MSK     ETP       NaN       NaN
# 5       6      Puschkin                   SPB     ETP       NaN       NaN
# 6       7       Ramenki                   MSK     ETP       NaN       NaN
# 7       8    Zelenograd                   MSK     ETP       NaN       NaN
# 8       9          Perm                  PERM     KEP       NaN       NaN
# 9      10        Kungur                  PERM     KEP       NaN       NaN
#
#    UserId:3  UserId:4  UserId:5  UserId:6     ...       City:Perm  \
# 0       NaN       NaN       NaN       NaN     ...             NaN
# 1       NaN       NaN       NaN       NaN     ...             NaN
# 2       NaN       NaN       NaN       NaN     ...             NaN
# 3       NaN       NaN       NaN       NaN     ...             NaN
# 4       NaN       NaN       NaN       NaN     ...             NaN
# 5       NaN       NaN       NaN       NaN     ...             NaN
# 6       NaN       NaN       NaN       NaN     ...             NaN
# 7       NaN       NaN       NaN       NaN     ...             NaN
# 8       NaN       NaN       NaN       NaN     ...             NaN
# 9       NaN       NaN       NaN       NaN     ...             NaN
#
#    City:Kungur  Region:Свердловская область  Region:SVE  Region:SPB  \
# 0          NaN                          NaN         NaN         NaN
# 1          NaN                          NaN         NaN         NaN
# 2          NaN                          NaN         NaN         NaN
# 3          NaN                          NaN         NaN         NaN
# 4          NaN                          NaN         NaN         NaN
# 5          NaN                          NaN         NaN         NaN
# 6          NaN                          NaN         NaN         NaN
# 7          NaN                          NaN         NaN         NaN
# 8          NaN                          NaN         NaN         NaN
# 9          NaN                          NaN         NaN         NaN
#
#    Region:MSK  Region:PERM  product:КЭП  product:KEP  product:ETP
# 0         NaN          NaN          NaN          NaN          NaN
# 1         NaN          NaN          NaN          NaN          NaN
# 2         NaN          NaN          NaN          NaN          NaN
# 3         NaN          NaN          NaN          NaN          NaN
# 4         NaN          NaN          NaN          NaN          NaN
# 5         NaN          NaN          NaN          NaN          NaN
# 6         NaN          NaN          NaN          NaN          NaN
# 7         NaN          NaN          NaN          NaN          NaN
# 8         NaN          NaN          NaN          NaN          NaN
# 9         NaN          NaN          NaN          NaN          NaN
#
# [10 rows x 32 columns]

# %%
for colunm in df.columns:
    for element in df[colunm]:
        print ("[] {}:{}".format(colunm,element))

# %%
df
# Out:
#    UserId          City                Region product  UserId:1  UserId:2  \
# 0       1  Екатеринбург  Свердловская область     КЭП       NaN       NaN
# 1       2       Puushma                   SVE     KEP       NaN       NaN
# 2       3         Piter                   SPB     KEP       NaN       NaN
# 3       4    Novouralsk                   SVE     ETP       NaN       NaN
# 4       5        Moscow                   MSK     ETP       NaN       NaN
# 5       6      Puschkin                   SPB     ETP       NaN       NaN
# 6       7       Ramenki                   MSK     ETP       NaN       NaN
# 7       8    Zelenograd                   MSK     ETP       NaN       NaN
# 8       9          Perm                  PERM     KEP       NaN       NaN
# 9      10        Kungur                  PERM     KEP       NaN       NaN
#
#    UserId:3  UserId:4  UserId:5  UserId:6     ...       City:Perm  \
# 0       NaN       NaN       NaN       NaN     ...             NaN
# 1       NaN       NaN       NaN       NaN     ...             NaN
# 2       NaN       NaN       NaN       NaN     ...             NaN
# 3       NaN       NaN       NaN       NaN     ...             NaN
# 4       NaN       NaN       NaN       NaN     ...             NaN
# 5       NaN       NaN       NaN       NaN     ...             NaN
# 6       NaN       NaN       NaN       NaN     ...             NaN
# 7       NaN       NaN       NaN       NaN     ...             NaN
# 8       NaN       NaN       NaN       NaN     ...             NaN
# 9       NaN       NaN       NaN       NaN     ...             NaN
#
#    City:Kungur  Region:Свердловская область  Region:SVE  Region:SPB  \
# 0          NaN                          NaN         NaN         NaN
# 1          NaN                          NaN         NaN         NaN
# 2          NaN                          NaN         NaN         NaN
# 3          NaN                          NaN         NaN         NaN
# 4          NaN                          NaN         NaN         NaN
# 5          NaN                          NaN         NaN         NaN
# 6          NaN                          NaN         NaN         NaN
# 7          NaN                          NaN         NaN         NaN
# 8          NaN                          NaN         NaN         NaN
# 9          NaN                          NaN         NaN         NaN
#
#    Region:MSK  Region:PERM  product:КЭП  product:KEP  product:ETP
# 0         NaN          NaN          NaN          NaN          NaN
# 1         NaN          NaN          NaN          NaN          NaN
# 2         NaN          NaN          NaN          NaN          NaN
# 3         NaN          NaN          NaN          NaN          NaN
# 4         NaN          NaN          NaN          NaN          NaN
# 5         NaN          NaN          NaN          NaN          NaN
# 6         NaN          NaN          NaN          NaN          NaN
# 7         NaN          NaN          NaN          NaN          NaN
# 8         NaN          NaN          NaN          NaN          NaN
# 9         NaN          NaN          NaN          NaN          NaN
#
# [10 rows x 32 columns]

# %%
for index, row in df.iterrows():
    print ("row {} index {} ".format(row, index))

# %%
for index, row in df.iterrows():
    for cl in original_columns:
        print ("index {} column {} value {}".format(index,cl,row[cl]))

# %%
for index, row in df.iterrows():
    for cl in original_columns:
        newdf.set_value(index,"{}:{}".format(cl,row[cl]),1)

# %%
newdf
# Out:
#    UserId          City                Region product  UserId:1  UserId:2  \
# 0       1  Екатеринбург  Свердловская область     КЭП       1.0       NaN
# 1       2       Puushma                   SVE     KEP       NaN       1.0
# 2       3         Piter                   SPB     KEP       NaN       NaN
# 3       4    Novouralsk                   SVE     ETP       NaN       NaN
# 4       5        Moscow                   MSK     ETP       NaN       NaN
# 5       6      Puschkin                   SPB     ETP       NaN       NaN
# 6       7       Ramenki                   MSK     ETP       NaN       NaN
# 7       8    Zelenograd                   MSK     ETP       NaN       NaN
# 8       9          Perm                  PERM     KEP       NaN       NaN
# 9      10        Kungur                  PERM     KEP       NaN       NaN
#
#    UserId:3  UserId:4  UserId:5  UserId:6     ...       City:Perm  \
# 0       NaN       NaN       NaN       NaN     ...             NaN
# 1       NaN       NaN       NaN       NaN     ...             NaN
# 2       1.0       NaN       NaN       NaN     ...             NaN
# 3       NaN       1.0       NaN       NaN     ...             NaN
# 4       NaN       NaN       1.0       NaN     ...             NaN
# 5       NaN       NaN       NaN       1.0     ...             NaN
# 6       NaN       NaN       NaN       NaN     ...             NaN
# 7       NaN       NaN       NaN       NaN     ...             NaN
# 8       NaN       NaN       NaN       NaN     ...             1.0
# 9       NaN       NaN       NaN       NaN     ...             NaN
#
#    City:Kungur  Region:Свердловская область  Region:SVE  Region:SPB  \
# 0          NaN                          1.0         NaN         NaN
# 1          NaN                          NaN         1.0         NaN
# 2          NaN                          NaN         NaN         1.0
# 3          NaN                          NaN         1.0         NaN
# 4          NaN                          NaN         NaN         NaN
# 5          NaN                          NaN         NaN         1.0
# 6          NaN                          NaN         NaN         NaN
# 7          NaN                          NaN         NaN         NaN
# 8          NaN                          NaN         NaN         NaN
# 9          1.0                          NaN         NaN         NaN
#
#    Region:MSK  Region:PERM  product:КЭП  product:KEP  product:ETP
# 0         NaN          NaN          1.0          NaN          NaN
# 1         NaN          NaN          NaN          1.0          NaN
# 2         NaN          NaN          NaN          1.0          NaN
# 3         NaN          NaN          NaN          NaN          1.0
# 4         1.0          NaN          NaN          NaN          1.0
# 5         NaN          NaN          NaN          NaN          1.0
# 6         1.0          NaN          NaN          NaN          1.0
# 7         1.0          NaN          NaN          NaN          1.0
# 8         NaN          1.0          NaN          1.0          NaN
# 9         NaN          1.0          NaN          1.0          NaN
#
# [10 rows x 32 columns]

# %%
newdf.loc[0:2].to_csv("test_first_lines.csv",index=False)

# %%
# Read sertain rows
import pandas as pd
pd.read_csv(r"C:\test.csv",usecols=[2])
